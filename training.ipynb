# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras import layers , models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical

from PIL import Image

import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
train = pd.read_csv('./train_without_na.csv')
test = pd.read_csv('./test.csv')

# %%
train['Category'].unique()
# Out:
# array(['Men Tshirts', 'Sarees', 'Kurtis', 'Women Tshirts',
#        'Women Tops & Tunics'], dtype=object)

# %%
category = ['Men Tshirts', 'Sarees', 'Kurtis', 'Women Tshirts',
       'Women Tops & Tunics']
target = [f'attr_{i}' for i in range(1 , 11)]

# %%
unique_class_in_each_target_label = []

# %%
for i in target:
    unique_class_in_each_target_label.append(train[i].nunique())

# %%
for i in unique_class_in_each_target_label:
    print(i)
# Out:
# 18
# 14
# 10
# 19
# 14
# 8
# 12
# 11
# 14
# 9

# %%
# For Kaggle

train['image_path'] = train.apply(lambda x: './Data/train_images/' + x['image_path'].split('/')[-1], axis=1)
test['image_path'] = test.apply(lambda x: './Data/test_images/' + x['image_path'].split('/')[-1], axis=1)

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomBrightness(0.1),
])

# %%
def prepare_images(image_paths, image_size=(224, 224)):
    """
    Converts image paths into augmented tensors using predefined data augmentation layers.
    
    Args:
        image_paths (list of str): List of image paths.
        image_size (tuple): Target size of images (height, width).
    
    Returns:
        np.array: Array of preprocessed and augmented image tensors.
    """

    images = []
    
    for path in image_paths:
        try:
            img = Image.open(path).convert("RGB")
            img = img.resize(image_size)  
            img_array = np.array(img) / 255.0  
            
            # Add batch dimension and convert to tensor
            img_tensor = tf.convert_to_tensor(img_array, dtype=tf.float32)
            img_tensor = tf.expand_dims(img_tensor, axis=0)  
            
            # Apply data augmentation
            augmented_img = data_augmentation(img_tensor)[0].numpy()  
            images.append(augmented_img)

        except Exception as e:
            print(f"Error loading image {path}: {e}")
    
    return np.array(images)

# %%
def predict_labels(unique_class_in_each_target_label, x_train, y_train, x_predict):
    """
    Train a ResNet50-based classifier and predict labels for multiple target labels.
    
    Args:
        unique_class_in_each_target_label (list): List of unique class counts for each target label.
        x_train (np.array): Preprocessed training images.
        y_train (list of np.array): List of labels for training images, one array per target.
        x_predict (np.array): Preprocessed images to predict.
    
    Returns:
        list of dict: List of dictionaries with structure {'id': <id>, 'label': <label>}.
    """
    
    # Convert each target label to categorical format
    y_train_categorical = [
        to_categorical(y_train[i], num_classes=unique_class_in_each_target_label[i])
        for i in range(len(unique_class_in_each_target_label))
    ]
    
    # Load the ResNet50 base model
    base_model = ResNet50(
        weights='./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', 
        include_top=False, 
        input_shape=(224, 224, 3)
    )
    base_model.trainable = False  
    
    # Define the model
    model = model(
        inputs=base_model.input,
        outputs=[
            Dense(num_classes, activation='softmax', name=f'target_{i+1}')(GlobalAveragePooling2D()(base_model.output))
            for i, num_classes in unique_class_in_each_target_label
        ]
    )

    # Compile the model
    model.compile(
        optimizer='adam', 
        loss=['categorical_crossentropy' for _ in unique_class_in_each_target_label], 
        metrics=['accuracy']
    )
    
    # Fit the model
    model.fit(
        x_train, 
        y_train_categorical, 
        epochs=4, 
        batch_size=32, 
        verbose=1
    )
    
    # Predict on the input
    predictions = model.predict(x_predict)
    y_predict = [np.argmax(pred, axis=1) for pred in predictions]
    
    return y_predict

# %%
predict_df = test[['id' , 'image_path']]
train_df = train[['id' , 'image_path' , 'attr_1','attr_2','attr_3','attr_4','attr_5','attr_6','attr_7','attr_8','attr_9','attr_10']]

le = LabelEncoder()

for i in target:
    train_df[i] = le.fit_transform(train_df[i])

class_to_label = dict(zip(le.classes_, range(len(le.classes_))))
label_to_class = {v:k  for k, v in class_to_label.items()}

y_train = train_df[target]

x_train = prepare_images(train_df['image_path'])
x_predict = prepare_images(predict_df['image_path'])

y_predict = predict_labels(
    unique_class_in_each_target_label,
    x_train,
    y_train,
    x_predict
)
        
# Step 3: Prepare final result
predict_df['label'] = [label_to_class[label] for label in y_predict]
result = predict_df[['id', 'label']]

result.to_csv(f'submission.csv', index=False)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22884\3963779241.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i] = le.fit_transform(train_df[i])
# Error loading image ./Data/train_images/040389.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040394.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040395.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040396.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040397.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040398.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040399.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040400.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040401.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040402.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040403.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040404.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040405.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040406.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040407.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040408.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040409.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040410.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040411.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040412.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040413.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040414.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040415.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040416.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040417.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040418.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040419.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040420.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040421.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040422.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040423.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040424.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040425.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040426.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040427.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040428.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040429.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040430.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040431.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040432.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040433.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040434.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040435.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040436.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040437.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040438.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040439.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040440.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040441.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040442.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040443.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040444.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040445.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040446.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040447.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040448.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040449.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040450.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040451.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040452.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040453.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040454.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040455.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040456.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040457.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040458.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040459.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040460.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040461.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040462.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040463.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040464.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040465.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040466.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040467.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040468.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040469.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040470.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040471.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040472.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040473.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040474.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040475.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040476.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040603.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040604.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040605.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040606.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040607.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040608.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040609.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040741.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040742.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040783.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040790.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040791.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040792.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040793.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040794.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040795.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040796.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040797.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040798.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040799.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040800.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040801.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040802.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040803.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040804.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040807.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040809.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040810.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040811.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040812.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040813.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040814.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040815.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040816.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040817.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040818.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040819.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040820.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040821.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040822.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040823.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040824.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040825.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040826.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040827.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040828.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040829.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040830.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040831.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040832.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040833.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040834.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040835.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040836.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040837.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040838.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040839.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040840.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040841.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040842.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040843.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040844.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040845.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040846.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040847.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040848.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040849.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040850.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040851.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040852.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040853.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040854.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040855.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040862.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040863.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040864.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040868.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040869.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040870.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040871.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040872.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040873.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040874.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040875.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040876.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040877.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040878.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040879.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040893.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040894.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040895.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040915.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040916.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040917.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040918.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040919.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040921.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040922.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040923.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040924.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040925.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040926.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040927.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040928.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040929.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040930.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040931.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040932.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040933.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040934.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040935.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040936.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040937.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040938.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040939.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040940.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040941.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040942.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040943.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040944.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040945.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040946.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040947.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040948.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/040949.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041031.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041032.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041033.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041034.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041035.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041036.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041037.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041038.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041039.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041040.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041041.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041042.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041043.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041044.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041045.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041046.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041047.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041048.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041049.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041050.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041051.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041052.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041053.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041054.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041055.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041056.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041057.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041058.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041059.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041060.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041061.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041062.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041063.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041064.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041065.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041066.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041067.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041068.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041069.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041070.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041071.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041072.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041073.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041074.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041075.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041076.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041077.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041078.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041079.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041080.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041081.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041082.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041083.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041084.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041085.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041086.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041087.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041088.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041091.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041092.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041093.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041094.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041095.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041096.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041097.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041098.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041099.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041100.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041101.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041102.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041103.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041104.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041105.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041106.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041107.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041108.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041109.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041110.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041111.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041112.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041113.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041114.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041115.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041116.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041117.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041118.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041119.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041120.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041121.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041122.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041123.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041124.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041125.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041126.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041127.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041128.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041129.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041130.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041131.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041132.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041133.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041134.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041135.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041136.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/041137.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# ...
# Error loading image ./Data/train_images/042935.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042936.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042937.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042938.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042939.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042940.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042941.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042942.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042943.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042944.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042945.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042946.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042947.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042948.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042949.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042950.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042951.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042952.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042953.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042954.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042955.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042956.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042957.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042958.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042959.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042960.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042961.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042962.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042963.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042964.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042965.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042966.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042967.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042968.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042969.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042970.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042971.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042972.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042973.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042974.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042975.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042976.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042977.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042978.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042979.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042980.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042981.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042982.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042983.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042984.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042985.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042986.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042987.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042988.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042989.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042990.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042991.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042992.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042993.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042994.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042995.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042996.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042997.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042998.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/042999.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043000.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043001.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043002.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043003.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043004.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043005.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043006.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043007.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043008.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043009.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043010.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043011.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043012.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043013.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043030.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043031.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043032.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043033.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043034.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043035.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043036.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043037.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043038.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043039.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043040.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043041.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043042.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043043.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043044.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043045.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043046.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043047.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043048.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043049.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043050.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043051.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043052.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043053.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043054.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043055.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043056.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043057.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043058.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043059.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043060.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043061.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043062.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043063.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
# Error loading image ./Data/train_images/043064.jpg: Unable to allocate 1.15 MiB for an array with shape (224, 224, 3) and data type float64
